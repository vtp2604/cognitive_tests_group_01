# %%
import matplotlib.pyplot as plt

# %%
male_scores = [14, 8, 16, 13, 11, 14, 10, 18, 10, 8, 6, 0, 10, 12, 14, 12, 3, 12, 0, 13, 14, 16]
female_scores = [18, 9, 6, 17, 6, 6, 18, 12, 13, 17, 12, 2, 12, 12, 16, 10, 18, 8]
fig, ax = plt.subplots()
ax.boxplot([male_scores, female_scores], labels=['Male', 'Female'])
plt.title("Male vs Female Results in the ANS Test")
plt.xlabel("Gender")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
male_scores = [1, 3, 6, 2, 5, 8, 5, 4, 3, 2, 3, 6, 8, 4, 3, 4, 9, 8, 4, 5]
female_scores = [2, 3, 6, 2, 5, 4, 7, 2, 1, 3, 2, 4, 8, 3, 5, 4]
fig, ax = plt.subplots()
ax.boxplot([male_scores, female_scores], labels=['Male', 'Female'])
plt.title("Male vs Female Results in the Spatial Reasoning Test")
plt.xlabel("Gender")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
male_scores = [21, 27, 24, 22, 12, 19, 26, 27, 26, 18, 30, 26, 16, 17, 30, 27, 27, 27, 19]
female_scores = [22, 24, 30, 26, 26, 27, 22, 22, 20, 15, 24, 27, 13, 20, 22, 15, 21, 23, 24]
fig, ax = plt.subplots()
ax.boxplot([male_scores, female_scores], labels=['Male', 'Female'])
plt.title("Male vs Female Results in the Maths Test")
plt.xlabel("Gender")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
male_scores = [11, 12, 7, 8, 9, 12, 13, 13, 10, 11]
female_scores = [12, 10, 13, 12, 12, 11, 7, 8, 7, 3, 14]
fig, ax = plt.subplots()
ax.boxplot([male_scores, female_scores], labels=['Male', 'Female'])
plt.title("Male vs Female Results in the Memory Test")
plt.xlabel("Gender")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')
